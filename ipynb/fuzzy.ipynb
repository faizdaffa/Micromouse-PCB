# %%
import numpy as np
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.pyplot as plt

# %%
xDekat = [0,10,20,40]
yDekat = [1,1,0,0]
xJauh = [0,20,30,40]
yJauh = [0,0,1,1]
xSedang = [0,10,20,30,40]
ySedang = [0,0,1,0,0]

fig, ax1 = plt.subplots(figsize=(10, 4))
ax1.set_title('Fungsi Keanggotaan Input (Ultrasonik Kiri, Depan, Kanan)', weight='bold')
ax1.set_xlabel('Jarak (cm)', weight='bold')
ax1.set_ylabel('Membership Value', weight='bold')

ax1.text(2.5  ,1.05, 'Dekat', weight='bold')
ax1.text(18.5 ,1.05, 'Sedang', weight='bold')
ax1.text(33.5 ,1.05, 'Jauh', weight='bold')
ax1.set_ylim([0,1.15])

ax1.set_facecolor('#ffff99')

ax1.plot(xSedang,ySedang, color='g')
ax1.plot(xDekat,yDekat, color='b')
ax1.plot(xJauh,yJauh, color='r')

# %%
xKiri = [-90,-45,0,90]
yKiri = [1,1,0,0]
xKanan = [-90,0,45,90]
yKanan = [0,0,1,1]
xLurus = [-90,-45,0,45,90]
yLurus = [0,0,1,0,0]

fig, ax = plt.subplots(figsize=(10, 4))

ax.set_title('Fungsi Keanggotaan Sudut', weight='bold')
ax.set_xlabel('Sudut (derajat)', weight='bold')
ax.set_ylabel('Membership Value', weight='bold')

ax.text(-73  ,1.05, 'Kiri', weight='bold')
ax.text(-6 ,1.05, 'Lurus', weight='bold')
ax.text(60 ,1.05, 'Kanan', weight='bold')
ax.set_xlim([-100,100])
ax.set_ylim([0,1.15])

#ax.set_yticklabels(ax.get_yticks(), weight='bold')
ax.set_xticklabels(ax.get_xticks(), weight='bold')

ax.xaxis.set_major_locator(MultipleLocator(45))
ax.xaxis.set_major_formatter('{x:.0f}')

ax.set_facecolor('#cce6ff')

ax.plot(xLurus,yLurus, color='g')
ax.plot(xKiri,yKiri, color='b')
ax.plot(xKanan,yKanan, color='r')
# Out:
# c:\Users\faizd\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
xKiri = [-90,-90]
yKiri = [0,1]
xKanan = [90,90]
yKanan = [0,1]
xLurus = [0,0]
yLurus = [0,1]

fig, ax = plt.subplots(figsize=(10, 4))

ax.set_title('Fungsi Keanggotaan Sudut', weight='bold')
ax.set_xlabel('Sudut (derajat)', weight='bold')
ax.set_ylabel('Membership Value', weight='bold')

ax.text(-95,1.05, 'Kiri', weight='bold')
ax.text(-8 ,1.05, 'Lurus', weight='bold')
ax.text(80 ,1.05, 'Kanan', weight='bold')
ax.set_xlim([-150,150])
ax.set_ylim([0,1.15])

#ax.set_yticklabels(ax.get_yticks(), weight='bold')
ax.set_xticklabels(ax.get_xticks(), weight='bold')

ax.xaxis.set_major_locator(MultipleLocator(90))
ax.xaxis.set_major_formatter('{x:.0f}')

ax.set_facecolor('#cce6ff')

ax.plot(xLurus,yLurus, color='g')
ax.plot(xKiri,yKiri, color='b')
ax.plot(xKanan,yKanan, color='r')
# Out:
# c:\Users\faizd\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
#========================Plotting Jurnal========================
xnear = [0,80,400,480]
ynear = [1,1,0,0]
xfar = [0,80,400,480]
yfar = [0,0,1,1]

fig, ax = plt.subplots(figsize=(10, 4))

ax.set_xlabel('input of left-obs')
ax.set_ylabel('Degree of membership')

ax.text(30 ,1.05, 'near')
ax.text(430 ,1.05, 'far')
#ax.set_xlim([-100,100])
ax.set_ylim([0,1.15])

#ax.set_yticklabels(ax.get_yticks(), weight='bold')
#ax.set_xticklabels(ax.get_xticks(), weight='bold')

ax.xaxis.set_major_locator(MultipleLocator(50))
ax.xaxis.set_major_formatter('{x:.0f}')

#ax.set_facecolor('#cce6ff')

ax.plot(xnear,ynear, color='b')
ax.plot(xfar,yfar, color='g')

# %%
#========================Plotting Jurnal========================
xleft = [-90,-30,0,90]
yleft = [1,1,0,0]
xright = [-90,0,30,90]
yright = [0,0,1,1]
xfront = [-90,-30,0,30,90]
yfront = [0,0,1,0,0]

fig, ax = plt.subplots(figsize=(10, 4))

ax.set_xlabel('input of target-angle')
ax.set_ylabel('Degree of membership')

ax.text(-73  ,1.05, 'left')
ax.text(-6 ,1.05, 'front')
ax.text(60 ,1.05, 'right')
#ax.set_xlim([-100,100])
ax.set_ylim([0,1.15])

#ax.set_yticklabels(ax.get_yticks(), weight='bold')
#ax.set_xticklabels(ax.get_xticks(), weight='bold')

ax.xaxis.set_major_locator(MultipleLocator(20))
ax.xaxis.set_major_formatter('{x:.0f}')

#ax.set_facecolor('#cce6ff')

ax.plot(xfront,yfront, color='g')
ax.plot(xleft,yleft, color='b')
ax.plot(xright,yright, color='r')

# %%
xslow  = [0,2,4,12]
yslow  = [1,1,0,0]
xLslow = [0,2,4,6,12]
yLslow = [0,0,1,0,0]
xmid   = [0,4,6,8,12]
ymid   = [0,0,1,0,0]
xLfast = [0,6,8,10,12]
yLfast = [0,0,1,0,0]
xfast  = [0,8,10,12]
yfast  = [0,0,1,1]

fig, ax = plt.subplots(figsize=(10, 4))

ax.set_xlabel('output of left-v')
ax.set_ylabel('Degree of membership')

ax.text(0.7 ,1.05, 'slow')
ax.text(3.6 ,1.05, 'L-slow')
ax.text(5.8 ,1.05, 'mid')
ax.text(7.7 ,1.05, 'L-fast')
ax.text(10.5 ,1.05, 'fast')
#ax.set_xlim([-100,100])
ax.set_ylim([0,1.15])

ax.xaxis.set_major_locator(MultipleLocator(2))
ax.xaxis.set_major_formatter('{x:.0f}')

#ax.set_facecolor('#cce6ff')

ax.plot(xslow,yslow,   color='b')
ax.plot(xLslow,yLslow, color='g')
ax.plot(xmid,ymid,     color='r')
ax.plot(xLfast,yLfast, color='c')
ax.plot(xfast,yfast,   color='m')
