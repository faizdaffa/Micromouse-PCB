# %%
# !pip install scikit-fuzzy
# Out:
# Collecting scikit-fuzzy
#   Downloading scikit-fuzzy-0.4.2.tar.gz (993 kB)
#      -------------------------------------- 994.0/994.0 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.6.0 in c:\users\faizd\appdata\local\programs\python\python37\lib\site-packages (from scikit-fuzzy) (1.21.6)
# Requirement already satisfied: scipy>=0.9.0 in c:\users\faizd\appdata\local\programs\python\python37\lib\site-packages (from scikit-fuzzy) (1.7.3)
# Collecting networkx>=1.9.0
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ---------------------------------------- 1.9/1.9 MB 7.7 MB/s eta 0:00:00
# Installing collected packages: networkx, scikit-fuzzy
#   Running setup.py install for scikit-fuzzy: started
#   Running setup.py install for scikit-fuzzy: finished with status 'done'
# Successfully installed networkx-2.6.3 scikit-fuzzy-0.4.2
#   DEPRECATION: scikit-fuzzy is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.pyplot as plt

# %%
x1_US = [0,10,20,30,40]
y1_US = [1,1,0,1,1]
x2_US = [0,10,20,30,40]
y2_US = [0,0,1,0,0]

fig, ax1 = plt.subplots(figsize=(10, 4))
ax1.set_title('Fungsi Keanggotaan Ultrasonik Kiri', weight='bold')
ax1.set_xlabel('Jarak (cm)', weight='bold')
ax1.set_ylabel('Membership Value', weight='bold')

ax1.text(2.5  ,1.05, 'Dekat', weight='bold')
ax1.text(18.5 ,1.05, 'Sedang', weight='bold')
ax1.text(33.5 ,1.05, 'Jauh', weight='bold')
ax1.set_ylim([0,1.15])

ax1.set_facecolor('#ffff66')

ax1.plot(x1_US,y1_US, color='k')
ax1.plot(x2_US,y2_US, color='k')

# %%
x1_sudut = [-90,-45,0,45,90]
y1_sudut = [1,1,0,1,1]
x2_sudut = [-90,-45,0,45,90]
y2_sudut = [0,0,1,0,0]


fig, ax = plt.subplots(figsize=(10, 4))

ax.set_title('Fungsi Keanggotaan Sudut', weight='bold')
ax.set_xlabel('Sudut (derajat)', weight='bold')
ax.set_ylabel('Membership Value', weight='bold')

ax.text(-73  ,1.05, 'Kiri', weight='bold')
ax.text(-6 ,1.05, 'Lurus', weight='bold')
ax.text(60 ,1.05, 'Kanan', weight='bold')
ax.set_xlim([-100,100])
ax.set_ylim([0,1.15])

#ax.set_yticklabels(ax.get_yticks(), weight='bold')
ax.set_xticklabels(ax.get_xticks(), weight='bold')

ax.xaxis.set_major_locator(MultipleLocator(45))
ax.xaxis.set_major_formatter('{x:.0f}')

ax.set_facecolor('#99ccff')

ax.plot(x1_sudut,y1_sudut, color='k')
ax.plot(x2_sudut,y2_sudut, color='k')
# Out:
# c:\Users\faizd\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
